# %%
# Basic Libraries
import numpy as np
import pandas as pd

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluation libraries
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

# Deep Learning libraries (TensorFlow Keras)
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, BatchNormalization, Dropout
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier

# %%
fashion_train=pd.read_csv('fashion-mnist_train.csv')
fashion_test=pd.read_csv('fashion-mnist_test.csv')

# %%
fashion_train.shape
# Out:
# (60000, 785)

# %%
# Splitting features and labels
X_train_fashion = fashion_train.drop('label', axis=1)
y_train_fashion = fashion_train['label']

X_test_fashion = fashion_test.drop('label', axis=1)
y_test_fashion = fashion_test['label']

# %%
# Reshaping the dataset
X_train_reshape = X_train_fashion.values.reshape(-1, 28, 28)
X_test_reshape = X_test_fashion.values.reshape(-1, 28, 28)

# %%
# Names of clothing accessories in order
col_names = [
    'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
    'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'
]

# Visualizing the images
plt.figure(figsize=(10, 10))

for i in range(15):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train_reshape[i], cmap='gray')
    plt.xlabel(col_names[y_train_fashion[i]])

plt.show()

# %%
y_train_fashion = to_categorical(y_train_fashion, num_classes=10)
y_test_fashion = to_categorical(y_test_fashion, num_classes=10)

# %%
#Creating base neural network model
model = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dropout(0.3),
    BatchNormalization(),

    Dense(24, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),

    Dense(24, activation='relu'),
    Dropout(0.3),
    BatchNormalization(),

    Dense(10, activation='softmax')
])

# %%
#Compiling the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
#Fitting the model
history = model.fit(
    X_train_fashion,
    y_train_fashion,
    batch_size=100,
    epochs=30,
    validation_data=(X_test_fashion, y_test_fashion)
)
# Out:
# Epoch 1/30
# 600/600 [==============================] - 3s 4ms/step - loss: 1.0965 - accuracy: 0.6138 - val_loss: 0.5540 - val_accuracy: 0.8132
# Epoch 2/30
# 600/600 [==============================] - 1s 2ms/step - loss: 0.7405 - accuracy: 0.7418 - val_loss: 0.4752 - val_accuracy: 0.8299
# Epoch 3/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.6725 - accuracy: 0.7701 - val_loss: 0.4548 - val_accuracy: 0.8417
# Epoch 4/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.6321 - accuracy: 0.7889 - val_loss: 0.4324 - val_accuracy: 0.8506
# Epoch 5/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.6083 - accuracy: 0.7984 - val_loss: 0.4561 - val_accuracy: 0.8541
# Epoch 6/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5870 - accuracy: 0.8055 - val_loss: 0.4612 - val_accuracy: 0.8573
# Epoch 7/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5847 - accuracy: 0.8069 - val_loss: 0.4440 - val_accuracy: 0.8598
# Epoch 8/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5678 - accuracy: 0.8127 - val_loss: 0.4412 - val_accuracy: 0.8613
# Epoch 9/30
# 600/600 [==============================] - 4s 7ms/step - loss: 0.5610 - accuracy: 0.8147 - val_loss: 0.4245 - val_accuracy: 0.8632
# Epoch 10/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5608 - accuracy: 0.8153 - val_loss: 0.4308 - val_accuracy: 0.8635
# Epoch 11/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5478 - accuracy: 0.8185 - val_loss: 0.4248 - val_accuracy: 0.8635
# Epoch 12/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.5421 - accuracy: 0.8206 - val_loss: 0.4398 - val_accuracy: 0.8702
# Epoch 13/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.5396 - accuracy: 0.8191 - val_loss: 0.4026 - val_accuracy: 0.8677
# Epoch 14/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5427 - accuracy: 0.8207 - val_loss: 0.4235 - val_accuracy: 0.8648
# Epoch 15/30
# 600/600 [==============================] - 4s 6ms/step - loss: 0.5360 - accuracy: 0.8224 - val_loss: 0.4252 - val_accuracy: 0.8712
# Epoch 16/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.5327 - accuracy: 0.8245 - val_loss: 0.4150 - val_accuracy: 0.8652
# Epoch 17/30
# 600/600 [==============================] - 3s 4ms/step - loss: 0.5251 - accuracy: 0.8273 - val_loss: 0.4382 - val_accuracy: 0.8666
# Epoch 18/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5243 - accuracy: 0.8274 - val_loss: 0.4240 - val_accuracy: 0.8635
# Epoch 19/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.5309 - accuracy: 0.8249 - val_loss: 0.4010 - val_accuracy: 0.8747
# Epoch 20/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5244 - accuracy: 0.8280 - val_loss: 0.4146 - val_accuracy: 0.8528
# Epoch 21/30
# 600/600 [==============================] - 4s 6ms/step - loss: 0.5195 - accuracy: 0.8287 - val_loss: 0.3920 - val_accuracy: 0.8639
# Epoch 22/30
# 600/600 [==============================] - 3s 6ms/step - loss: 0.5206 - accuracy: 0.8292 - val_loss: 0.3975 - val_accuracy: 0.8719
# Epoch 23/30
# 600/600 [==============================] - 2s 3ms/step - loss: 0.5093 - accuracy: 0.8305 - val_loss: 0.4240 - val_accuracy: 0.8682
# Epoch 24/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5109 - accuracy: 0.8325 - val_loss: 0.4151 - val_accuracy: 0.8723
# Epoch 25/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5128 - accuracy: 0.8324 - val_loss: 0.4090 - val_accuracy: 0.8654
# Epoch 26/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5031 - accuracy: 0.8341 - val_loss: 0.3971 - val_accuracy: 0.8703
# Epoch 27/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5053 - accuracy: 0.8319 - val_loss: 0.3990 - val_accuracy: 0.8727
# Epoch 28/30
# 600/600 [==============================] - 3s 5ms/step - loss: 0.5039 - accuracy: 0.8361 - val_loss: 0.3821 - val_accuracy: 0.8711
# Epoch 29/30
# 600/600 [==============================] - 4s 6ms/step - loss: 0.4990 - accuracy: 0.8362 - val_loss: 0.3986 - val_accuracy: 0.8692
# Epoch 30/30
# 600/600 [==============================] - 2s 4ms/step - loss: 0.5029 - accuracy: 0.8347 - val_loss: 0.3776 - val_accuracy: 0.8726

# %%
#Model Evaluation
test_loss_fashion, test_acc_fashion = model.evaluate(
    X_test_fashion,
    y_test_fashion
)

print("Fashion MNIST Test accuracy:", round(test_acc_fashion, 4))
# Out:
# 313/313 [==============================] - 0s 980us/step - loss: 0.3776 - accuracy: 0.8726
# Fashion MNIST Test accuracy: 0.8726

# %%
#predicting labels
y_predict_fash = model.predict(X_test_fashion)

# Convert probabilities to class labels
y_predict_fash = np.argmax(y_predict_fash, axis=1)
y_test_fash_eval = np.argmax(y_test_fashion, axis=1)
# Out:
# 313/313 [==============================] - 0s 1ms/step

# %%
#Confusion Matrix
con_mat = confusion_matrix(y_test_fash_eval, y_predict_fash)

plt.figure(figsize=(10, 10))
sns.heatmap(
    con_mat,
    annot=True,
    annot_kws={'size': 15},
    linewidths=0.5,
    fmt='d',
    cmap='gray'
)
plt.title('True vs False predicted Fashion MNIST', fontweight='bold', fontsize=15)
plt.show()

# %%
#Classification report
print(classification_report(y_test_fash_eval, y_predict_fash))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 #Classification report
# ----> 2 print(classification_report(y_test_fash_eval, y_predict_fash))
#
# NameError: name 'classification_report' is not defined

# %%
#Checking History Keys
print(history.history.keys())
dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
#plot training vs Validation Accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
#Plot training vs validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='best')
plt.show()

# %%
# Predicting a single image
y_predict = model.predict(X_test_fashion.iloc[0].values.reshape(1, -1))
y_predict = np.argmax(y_predict, axis=1)

# Names of clothing accessories
col_names = [
    'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
    'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'
]

plt.figure(figsize=(10, 10))
plt.imshow(X_train_reshape[0], cmap='gray')
plt.xlabel(
    "Actual: {}, Predicted: {}".format(
        col_names[np.argmax(y_test_fashion[0])],
        col_names[y_predict[0]]
    )
)
plt.show()
# Out:
# 1/1 [==============================] - 0s 35ms/step
